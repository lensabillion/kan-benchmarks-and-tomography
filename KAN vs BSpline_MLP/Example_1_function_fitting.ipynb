# %% [markdown]
# # Example 1: Function Fitting
#
# In this example, we will cover how to leverage grid refinement to maximimze KANs' ability to fit functions

# %% [markdown]
# intialize model and create dataset

# %%
from kan import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# initialize KAN with G=3
model = KAN(width=[2,1,1], grid=3, k=3, seed=1, device=device)

# create dataset
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2, device=device)
# Out:
# cpu
# checkpoint directory created: ./model
# saving model version 0.0

# %% [markdown]
# Train KAN (grid=3)

# %%
model.fit(dataset, opt="LBFGS", steps=20);
# Out:
# | train_loss: 1.40e-02 | test_loss: 1.42e-02 | reg: 1.18e+01 | : 100%|█| 20/20 [00:00<00:00, 23.82it
# saving model version 0.1

# %% [markdown]
# The loss plateaus. we want a more fine-grained KAN!

# %%
# initialize a more fine-grained KAN with G=10
model = model.refine(10)
# Out:
# saving model version 0.2

# %% [markdown]
# Train KAN (grid=10)

# %%
model.fit(dataset, opt="LBFGS", steps=20);
# Out:
# | train_loss: 9.42e-04 | test_loss: 1.08e-03 | reg: 1.18e+01 | : 100%|█| 20/20 [00:00<00:00, 39.47it
# saving model version 0.3

# %% [markdown]
# The loss becomes lower. This is good! Now we can even iteratively making grids finer.

# %%
from kan import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# create dataset
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2, device=device, train_num=1000)


grids = np.array([3,5,10,20,50,100])
#grids = np.array([3,10])


train_losses = []
test_losses = []
steps = 200
k = 3

for i in range(grids.shape[0]):
    if i == 0:
        model = KAN(width=[2,1,1], grid=grids[i], k=k, seed=0, device=device)
    if i != 0:
        model = model.refine(grids[i])
    results = model.fit(dataset, opt="LBFGS", steps=steps)
    train_losses += results['train_loss']
    test_losses += results['test_loss']
# Out:
# cpu
# checkpoint directory created: ./model
# saving model version 0.0
# | train_loss: 1.35e-02 | test_loss: 1.39e-02 | reg: 1.12e+01 | : 100%|█| 200/200 [00:02<00:00, 99.24
# saving model version 0.1
# saving model version 0.2
# | train_loss: 7.28e-03 | test_loss: 7.23e-03 | reg: 1.12e+01 | : 100%|█| 200/200 [00:01<00:00, 115.1
# saving model version 0.3
# saving model version 0.4
# | train_loss: 4.81e-04 | test_loss: 5.13e-04 | reg: 1.12e+01 | : 100%|█| 200/200 [00:02<00:00, 97.69
# saving model version 0.5
# saving model version 0.6
# | train_loss: 4.61e-05 | test_loss: 6.12e-05 | reg: 1.12e+01 | : 100%|█| 200/200 [00:02<00:00, 82.16
# saving model version 0.7
# saving model version 0.8
# | train_loss: 1.54e-05 | test_loss: 3.12e-05 | reg: 1.12e+01 | : 100%|█| 200/200 [00:03<00:00, 57.73
# saving model version 0.9
# saving model version 0.10
# | train_loss: 1.21e-05 | test_loss: 3.48e-05 | reg: 1.12e+01 | : 100%|█| 200/200 [00:02<00:00, 67.46
# saving model version 0.11

# %% [markdown]
# Training dynamics of losses display staircase structures (loss suddenly drops after grid refinement)

# %%
plt.plot(train_losses)
plt.plot(test_losses)
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
plt.yscale('log')

# %% [markdown]
# Neural scaling laws (For some reason, this got worse than pykan 0.0. We're still investigating the reason, probably due to the updates of curve2coef)

# %%
n_params = 3 * grids
train_vs_G = train_losses[(steps-1)::steps]
test_vs_G = test_losses[(steps-1)::steps]
plt.plot(n_params, train_vs_G, marker="o")
plt.plot(n_params, test_vs_G, marker="o")
plt.plot(n_params, 100*n_params**(-4.), ls="--", color="black")
plt.xscale('log')
plt.yscale('log')
plt.legend(['train', 'test', r'$N^{-4}$'])
plt.xlabel('number of params')
plt.ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')
